# %% [markdown]
# # SQL in Python

# %% [markdown]
# SQL is a formal language for communicating with a database to articulate precisely what information you want from a collection of database tables.
#
# SQL is one of the most commonly used languages in the world (currently the 9th most popular programming language according to [Code-dojo](https://www.codingdojo.com/blog/the-7-most-in-demand-programming-languages-of-2019)!).  You **will** have to interact with it at some point if you work with data.  Probably quite often.
#
# Relational databases are *structured* repositories for data, consisting of *tables* that are _related_ to each other.
#
# * A table has **typed columns**, in that each element in a specific column has the same data type.
# * The **schema** of the database specifies the structure of the table, where each column has a **name** associated with it, and a specified **data type**.
# * The entries are the **rows** in the table.
# * A SQL database can consist of one or more tables.
#
# Usually, we write SQL _queries_ to get the data we want, in a Workbench, CLI, or other provided interface. But we can connect to databases directly with tools in Python!

# %% [markdown]
# ## `SQL` magic

# %% [markdown]
# Since we're working in a Jupyter notebook here, we can take advantage of the `sql` magic. This will look just like a traditional Workbench interface.
#
# First we activate it, and tell it to connect to our database. This is a database containing the objects at the [Minneapolis Institute of Art](http://artsmia.org/). You can find the raw data used to construct this database [here](https://github.com/artsmia/collection).

# %%
# %load_ext sql
# %sql postgresql://rich:testpass@localhost:5432/art

# %% [markdown]
# Note the structure of the connection string, it consists of all the information our system needs:
#
# ```
# flavor://username:password@url:port/database
# ```
#
# This is a PostgreSQL database.  There are many flavors or dialects of SQL, the most common are
#
# - SQLite ([docs](https://www.sqlite.org/lang.html))
# - PostgreSQL (sometimes just written Postgres) ([docs](https://www.postgresql.org/docs/manuals/))
# - MySQL ([docs](https://dev.mysql.com/doc/), click on the reference manual)
# - Oracle ([docs](https://docs.oracle.com/en/database/oracle/oracle-database/index.html))
# - MS SQL Server ([docs](https://docs.microsoft.com/en-us/sql/sql-server/))
#
# They differ in details about how they work and how you perform certain tasks, but all (mostly) conform to the SQL standards. That means basic things like simple queries (what we'll be doing) will look the same.
#
# The username, password, and url are hopefully self explanatory. We need to go to a particular host, and log in. In this case, the URL is `localhost`, indicating this is running locally (i.e. on my laptop).
#
# The port is another part of internet infrastructure, each host (including your computer) has many ports. Think of them as slots that something can connect to. Some are dedicated to particular uses (80 for http, 443 for https, 22 for ssh, etc), but most are open. Postgres doesn't have a reserved port, but most Postgres servers default to `5432`.
#
# The database is precisely that.  A host can have multiple independent databases, each with their own tables, logins, and users.
#
# With a connection, we can write a basic query. This database only has one table called `mia`, let's see what's in it.

# %%
# %%sql
#
# SELECT *
# FROM mia
# LIMIT 5;
# Out:
#  * postgresql://rich:***@localhost:5432/art
# 5 rows affected.
# [(10583, 'P.70.72', 'Artist: Francisco Toledo', 'Mexican, 1940 - 2019', 'Benda Hua', ' Prints', 'Arts of the Americas', 'North America', 'Mexico', None, 'Gift of Mrs. Patrick Butler, by exchange', 'c. 1969', 'Woman swimming underwater, with shrimp caught in a fishing net', None, 'White-line etching and drypoint (top-rolled)', '20th century', '', 'Numbered in pencil, LL: 1/25', 'Not on View'),
#  (10584, 'P.11,377', 'Artist: Philip Little', 'American, 1857 - 1942', 'Outer Harbor, Gloucester', ' Prints', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Philip Little in memory of Annie Jeannette Jackson, 1931', '1915', '', None, 'Etching', '20th century', '', '', 'Not on View'),
#  (10585, 'P.13,434', 'Artist: Clara Gardner Mairs', 'American, 1878 - 1963', 'Shadrack Meshach and Abendigo', ' Prints', 'Prints and Drawings', 'North America', 'United States', None, 'Gift of Clement Haupers, 1965', '20th century', '', None, 'Etching, aquatint on cream wove paper', '20th century', '', '', 'Not on View'),
#  (10586, 'P.82.40.245', 'Artist: Winslow Homer', 'American, 1836–1910', "On the Beach at Long Branch - The Children's Hour", ' Prints', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Dr. and Mrs. Robert D. Semsch', '1874', '', None, 'Wood engraving', '19th century', '', '', 'Not on View'),
#  (10587, 'P.11,368', 'Artist: Philip Little', 'American, 1857 - 1942', "The Voyagers - Mother's Tablecloth", ' Prints', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Philip Little in memory of Annie Jeannette Jackson, 1931', '1919', '', None, 'Etching', '20th century', '', '', 'Not on View')]

# %% [markdown]
# Lots of information about the different objects in the collection.  How many objects are there?  We can use `COUNT`.

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM mia;
# Out:
#  * postgresql://rich:***@localhost:5432/art
# 1 rows affected.
# [(97816,)]

# %% [markdown]
# That's a lot. We've already seen that we can `LIMIT` how many we get, we can also determine where we start with `OFFSET`.

# %%
# %%sql
#
# SELECT *
# FROM mia
# ORDER BY index
# OFFSET 10 LIMIT 5;
# Out:
#  * postgresql://rich:***@localhost:5432/art
# 5 rows affected.
# [(10, '96.146.166.1', 'Artist: Yanagawa Shigenobu II; Publisher: Hirabayashi Shōgorō', 'Japanese', "Yanagawa's Picture Book: Volume of Animals (vol. 1)", ' Books', 'Asian Art', 'Asia', 'Japan', None, 'Bequest of Louis W. Hill, Jr.', 'c. 1856', "pale green, textured soft cover; two bound with green string, one bound with pink string; each has yellow text label along UL edge of front cover; other #'s J170-22", None, 'Woodblock printed book; ink and limited color on paper', '19th century', '', 'Censor:kai,\r\nPublisher: 収文堂 Shūbundō shi(on the back of cover)', 'Not on View'),
#  (11, '2007.35.84', 'Photographer: Harold E. Edgerton', 'American, 1903 - 1990', 'Two Fencers', ' Photographs', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Frederick B. Scheel', '1938', 'multiple exposure image of two figures in white, fencing', None, 'Gelatin silver print', '20th century', '', '', 'Not on View'),
#  (12, '96.146.23', 'Artist: after Takeuchi Seihō', 'Japanese, 1864 - 1942', 'Birds and a Radish', ' Paintings', 'Asian Art', 'Asia', 'Japan', None, 'Bequest of Louis W. Hill, Jr.', '20th century', 'Hill # R-31', None, 'Ink and color on paper', '20th century', '', "\\'Seiho\\' with seal at LRC", 'Not on View'),
#  (13, '2007.35.296', 'Photographer: Minor White', 'American, 1908 - 1976', 'Moencopi Strata, Capital Reef, Utah', ' Photographs', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Frederick B. Scheel', '1962', '', None, 'Gelatin silver print', '20th century', '', '', 'Not on View'),
#  (14, '96.146.155.9', 'Artist: Utagawa Kunisada; Artist: Utagawa Hiroshige; Publisher: Maruya Kyūshirō; Carver: Yokogawa Takejirō', 'Japanese, 1797 - 1858', 'Narumi', ' Prints', 'Asian Art', 'Asia', 'Japan', None, 'Bequest of Louis W. Hill, Jr.', '1855, 8th month', '', None, 'Woodblock print (nishiki-e); ink and color on paper', '19th century', '', "date seal: 卯八 {u hachi} (Hare 8) | censor seal: 改 {aratame} (inspected) | publisher\\'s seal: {Marukyū} | carver\\'s seal: {hori Take}", 'Not on View')]

# %% [markdown]
# We'll also want to get subsets, we can do that with `WHERE`.  In this collection, the continents with meaningful data, in decreasing order of number of objects, are Europe, North America, Asia, Africa, South America, Oceania, and NULL (i.e. ones without a continent). Let's only get ones from North America.

# %%
# %%sql
#
# SELECT *
# FROM mia
# WHERE continent = 'North America' AND country = 'United States'
# ORDER BY index
# LIMIT 5;
# Out:
#  * postgresql://rich:***@localhost:5432/art
# 5 rows affected.
# [(5, '2002.279.20', 'Artist: Adolf Dehn', 'American, 1895–1968', 'Chapric and Murka', ' Drawings', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Mrs. Adolf Dehn', '1922', '', None, 'Brush and black ink on ivory wove paper', '20th century', '', "inscribed in black ink, UL corner, \\'Adolf Dehn 1922 Wein\\'", 'Not on View'),
#  (11, '2007.35.84', 'Photographer: Harold E. Edgerton', 'American, 1903 - 1990', 'Two Fencers', ' Photographs', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Frederick B. Scheel', '1938', 'multiple exposure image of two figures in white, fencing', None, 'Gelatin silver print', '20th century', '', '', 'Not on View'),
#  (13, '2007.35.296', 'Photographer: Minor White', 'American, 1908 - 1976', 'Moencopi Strata, Capital Reef, Utah', ' Photographs', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Frederick B. Scheel', '1962', '', None, 'Gelatin silver print', '20th century', '', '', 'Not on View'),
#  (17, '2007.35.314', 'Photographer: William A. Garnett', 'American, born 1916', 'Nude Dune, Death Valley, California', ' Photographs', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Frederick B. Scheel', '1954', 'dune with light and shadows suggesting a nude figure', None, 'Gelatin silver print', '20th century', '', '', 'Not on View'),
#  (27, '2002.279.4', 'Artist: Adolf Dehn', 'American, 1895–1968', 'Consumptive Girl (or TB)', ' Prints', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Mrs. Adolf Dehn', '1926', '', None, 'Drypoint', '20th century', '', "\\'Adolf Dehn 1926\\', LL; \\'12 prints\\', LL; \\'T.B.\\', LC; \\'ET-6 22\\', verso, UL", 'Not on View')]

# %% [markdown]
# And how many of these are there?

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM mia
# WHERE continent = 'North America';
# Out:
#  * postgresql://rich:***@localhost:5432/art
# 1 rows affected.
# [(31330,)]

# %% [markdown]
# Still a lot.
#
# Let's look for a particular artist. Do they have anything by Picasso? We'll use `ILIKE`, the case insensitive search. In that, a `%` is a wildcard, like a `*` in Bash.

# %%
# %%sql
#
# SELECT artist, title, dated
# FROM mia
# WHERE artist ILIKE '%picasso%'
# Out:
#  * postgresql://rich:***@localhost:5432/art
# 79 rows affected.
# [('Artist: Pablo Picasso', 'Taureau de Profil', '1945'),
#  ('Artist: Pablo Picasso', 'Le Combat', '1937'),
#  ('Artist: Pablo Picasso', 'Les pauvres', '1905 (printed 1913)'),
#  ('Artist: Pablo Picasso', 'Après la Pique', '1959'),
#  ('Artist: Pablo Picasso; Publisher: Ambroise Vollard; Printer: Louis Fort, Paris, France', 'Les deux saltimbanques', '1905 (published 1913)'),
#  ('Artist: Pablo Picasso', 'Tête de Femme de Profil', '1905 (printed 1913)'),
#  ("Artist: Pablo Picasso; Printer: L'Atelier Desjobert, Paris", 'Le Peintre et son Modèle', '1930'),
#  ('Artist: Pablo Picasso', 'Le Singe', '1936'),
#  ('Artist: Pablo Picasso; Printer: Auguste Delâtre', 'Le repas frugal', 'September 1904 (printed 1913)'),
#  ('Artist: Pablo Picasso; Printer: Aldo Crommelyck', 'Painter at Work with a Bearded Model and a Seated Spectator', '1963'),
#  ('Artist: Pablo Picasso', 'Portrait of Ambrose Vollard, II', '1937 (printed and published 1939)'),
#  ('Artist: Pablo Picasso', 'Portrait of Ambroise Vollard, III', '1937 (printed and published 1939)'),
#  ('Artist: Pablo Picasso; Publisher: Mourlot Freres, Paris', 'Hibou, verre at fleur', '1956'),
#  ('Artist: Pablo Picasso', 'A Disheveled Woman', '1901'),
#  ('Maker: Pablo Picasso', 'Stirrup jar', 'c. 1950'),
#  ('Artist: Pablo Picasso; Printer: Arnéra, Vallauris, France', 'Le Banderillero (first state)', '1959'),
#  ('Artist: Pablo Picasso; Printer: Arnéra, Vallauris, France', 'Le Banderillero (fourth state)', '1959'),
#  ('Artist: Pablo Picasso; Printer: Arnéra, Vallauris, France', 'Le Banderillero (third state)', '1959'),
#  ('Artist: Pablo Picasso; Printer: Arnéra, Vallauris, France', 'Le Banderillero (second state)', '1959'),
#  ('Artist: Pablo Picasso; Author: Poem by Pablo Picasso', 'Text page from Sueño y Mentira de Franco (The Dream and Lie of Franco)', '1937'),
#  ('Artist: Pablo Picasso; Author: Pablo Picasso; Publisher: Pablo Picasso', 'Cover from Sueño y Mentira de Franco (Dream and Lie of Franco)', 'January 8 and 9, June 7, 1937'),
#  ('Artist: Pablo Picasso; Printer: Atelier Roger Lacourière, Paris, France (etchings)', 'Dream and Lie of Franco, Plate 1', 'January 8, 1937'),
#  ('Artist: Pablo Picasso; Printer: Atelier Roger Lacourière, Paris, France (etchings)', 'Dream and Lie of Franco, Plate 2', 'January 8 and 9, June 7, 1937'),
#  ('Artist: Pablo Picasso; Maker: Madoura Pottery, Vallauris, France', 'Vase', '1950'),
#  ('Maker: Pablo Picasso', 'Face No.111', '1963'),
#  ('Maker: Pablo Picasso', 'Joie de Vivre', 'c. 1956'),
#  ('Artist: Pablo Picasso; Publisher: Berggruen and Company', "Cover for an Exhibition Catalogue: Picasso, Dessins d'un Demi-Siècle", '1956'),
#  ('Artist: Pablo Picasso', 'Baboon and Young', '1951'),
#  ('Artist: Pablo Picasso', 'Reclining Woman', '1920'),
#  ('Artist: Pablo Picasso', 'Woman in an Armchair', '1927'),
#  ('Artist: Pablo Picasso', 'Woman by the Sea', '1922'),
#  ('Artist: Pablo Picasso', 'The Water Carrier', '1904-1905'),
#  ('Artist: Pablo Picasso; Author: Pierre Reverdy', 'Page from Le Chant des Morts (The Song of the Dead)', '1948'),
#  ('Artist: Pablo Picasso; Author: Honoré de Balzac; Publisher: Ambroise Vollard; Woodcutter: Wood engraving by Georges Aubert, Paris, France; Printer: L ... (5 characters truncated) ... Fort, Paris, France (etchings); Printer: Georges Aubert, Paris, France (wood engravings); Printer: Aimé Jourde, Paris, France , (text and typography)', "Le chef d'oeuvre Inconnu (The Unknown Masterpiece)", '1931'),
#  ('Artist: Pablo Picasso; Author: Poems by Pierre Reverdy; Publisher: Tériade, Paris, France; Printer: Draeger Frères, Paris, France , (text and type); Lithographer: Printed by Mourlot Freres, Paris (lithography)', 'Le Chant des Morts (The Song of the Dead)', 'September 30, 1948'),
#  ('Artist: Pablo Picasso; Author: Georges Louis Leclerc, Comte de Buffon; Publisher: Martin Fabiani, Paris', 'The Cow from Histoire Naturelle (Natural History)', '1942'),
#  ('Artist: Pablo Picasso; Author: Pierre Reverdy', 'Cover from Le Chant des Morts (The Song of the Dead)', '1948'),
#  ('Artist: Pablo Picasso; Author: Georges Louis Leclerc, Comte de Buffon; Printer: Atelier Roger Lacourière, Paris, France , (prints); Printer: Fequet et Baudier, Paris, France , (text); Publisher: Martin Fabiani, Paris', "Histoire naturelle: Eaux-fortes originales pour les textes de Buffon (Natural History: Original Etchings for Buffon's Text)", '1936 (published 1942)'),
#  ('Artist: Pablo Picasso; Author: Georges Louis Leclerc, Comte de Buffon; Publisher: Martin Fabiani, Paris', 'The Donkey, from Histoire Naturelle (Natural History)', '1942'),
#  ('Artist: Pablo Picasso; Author: Georges Louis Leclerc, Comte de Buffon; Publisher: Martin Fabiani, Paris', 'The Horse, from Histoire Naturelle (Natural History)', '1942'),
#  ('Artist: Pablo Picasso; Author: Poems by Aimé Césaire; Publisher: Éditions Fragrance , Paris; Printer: Pierre Bouchet, Paris, France (text and typography); Printer: Atelier Roger Lacourière, Paris, France (prints)', 'Corps Perdu (Lost Body)', '1950'),
#  ('Artist: Pablo Picasso; Author: Pierre Reverdy', 'Title page from Le Chant des Morts (The Song of the Dead)', '1948'),
#  ('Maker: Pablo Picasso', 'Pigeon et ses Petits', '1947'),
#  ('Artist: Pablo Picasso', 'Bullfight', '20th century'),
#  ('Artist: Pablo Picasso', 'Portrait of Ambrose Vollard, II', '1937 (printed and published 1939)'),
#  ('Artist: Pablo Picasso', 'Plate', 'c. 1950'),
#  ('Artist: Pablo Picasso', 'Bird', '20th century'),
#  ('Artist: After Pablo Picasso', 'Pas de deux', '1925'),
#  ('Artist: Pablo Picasso; Author: Prosper Mérimée; Publisher: La Bibliotèque Française; Printer: Atelier Lacourière et Frélaut, Paris, France (engravings, aquatints); Printer: Imprimerie Union, Paris , (text and type)', 'Carmen', '1949'),
#  ('Artist: after Pablo Picasso; Publisher: Paul Rosenberg &amp; Co.', 'Le Tricorne (Three-cornered Hat)', '1920'),
#  ('Artist: Pablo Picasso; Author: Poems by Luis de Góngora y Argote; Translator: Z. Millner; Publisher: Les Grands Peintres, Modernes et le Livre, Paris ... (9 characters truncated) ...  Printer: Fequet et Baudier, Paris, France , (text); Printer: Atelier Roger Lacourière, Paris, France , (etchings); Book Binder: Pierre-Lucien Martin', 'Vingt poèmes de Góngora (Twenty Poems by Góngora)', '1948'),
#  ("Artist: Pablo Picasso; Author: Text attributed to Fernando de Rojas; Publisher: Editions de l'Atelier Crommelynck, Paris, France; Printer: Fequet et Baudier, Paris, France (text and typography); Printer: Atelier Crommelynck, Paris (etchings)", 'La Celestine (Carlota Valdivia)', '1971'),
#  ('Artist: Illustrations by Pablo Picasso; Author: Honoré de Balzac; Artist: Hand-painted chemise, slipcase, and endleaves by John Graham; Engraver: Woo ... (110 characters truncated) ... ouis Fort, Paris, France (etchings); Printer: Georges Aubert, Paris, France (wood engravings); Printer: Aimé Jourde, Paris, France (text, typography)', "Le Chef-d'oeuvre inconnu", '1931'),
#  ('Artist: Pablo Picasso', 'Faun Uncovering a Woman', '1936'),
#  ('Artist: Pablo Picasso', 'Vase', '1952'),
#  ('Artist: Pablo Picasso', 'Ex-Libris for Max Pellequer', '1930'),
#  ('Artist: Pablo Picasso; Author: Poems by Tristan Tzara; Publisher: Bordas, Paris, France; Lithographer: Printed by Mourlot Freres, Paris (lithographs); Printer: George Girard, Paris, France (text and typography)', "De Mémoire d'Homme (In Living Memory)", '1950'),
#  ('Artist: Pablo Picasso; Author: Michael Leiris; Publisher: Harcourt, Brace, Jovanovich Inc., New York; Publisher: Éditions de la Revue Verve, Paris; Printer: Draeger Frères, Paris, France , Paris; Printer: Mourlot Freres, Paris', 'Revue Verve: Picasso and the Human Comedy or the Avatars of Fat-Foot', '1954'),
#  ('Artist: Pablo Picasso; Author: Aristophanes; Translator: Gilbert Seldes; Publisher: The Limited Editions Club; Printer: The Limited Editions Club (text, typography, and reproductions); Printer: Atelier Lacourière et Frélaut, Paris, France (etchings)', 'Lysistrata', '1934'),
#  ('Artist: Pablo Picasso', 'Minotaure aveugle guidé par une fillette, III', '1934'),
#  ('Artist: Pablo Picasso', 'Portrait of Ambrose Vollard, II', '1937 (printed and published 1939)'),
#  ('Artist: Pablo Picasso', 'Figure with Striped Blouse', '1949'),
#  ('Artist: Pablo Picasso; Publisher: Atelier Roger Lacourière, Paris, France; Printer: Atelier Roger Lacourière, Paris, France', 'Femme torero. Dernier baiser?', 'June 12, 1934'),
#  ('Artist: Pablo Picasso; Publisher: Atelier Roger Lacourière, Paris, France; Printer: Atelier Roger Lacourière, Paris, France', 'La Grande corrida, avec femme torero', 'September 8,1934'),
#  ('Artist: Pablo Picasso', 'Portrait of D. H. Kahnweiler I', '1957'),
#  ('Artist: Pablo Picasso', 'Portrait of D. H. Kahnweiler II', '1957'),
#  ('Artist: Pablo Picasso', 'The Studio', '1948'),
#  ('Artist: Pablo Picasso', 'Les Trois Amies (The Three Friends)', '1927'),
#  ('Artist: Pablo Picasso', 'Portrait of D.H. Kahnweiler III', '1957'),
#  ('Artist: Pablo Picasso', 'Venus and Cupid', '1949'),
#  ('Author: Avant-propos by Albert Gleizes; Author: Epilogue by Jean Metzinger; Artist: after Georges Braque; Artist: after André Derain; Artist: Marcel  ... (173 characters truncated) ... o Picasso; Artist: Jacques Villon; Printer: Compagnie Française des Arts Graphiques, Paris; Publisher: Compagnie Française des Arts Graphiques, Paris', 'Du Cubisme', '1947'),
#  ('Artist: Pablo Picasso; Printer: Arnéra, Vallauris, France', 'Le Banderillero (pre-first state)', '1959'),
#  ("Artist: after Pablo Picasso; Author: Preface by Jaime Sabartès; Printer: Atelier Crommelynck, Paris; Colorist: Daniel Jacomet et Cie, Paris; Publisher: Au Vent d'Arles", 'Les Bleus de Barcelone', '1963'),
#  ('Artist: Pablo Picasso', 'Paysage a Vallauris', '1953'),
#  ('Photographer: David Seymour; Publisher: The International Center for Photography; Depicted: Pablo Picasso', 'Pablo Picasso and detail of "Guernica," France', '1937'),
#  ('Artist: Pablo Picasso', 'Pitcher', 'c. 1950'),
#  ('Artist: Pablo Picasso; Author: Robert Desnos; Publisher: Robert J. Godet, Paris, France', 'Contrée', '1944'),
#  ('Artist: Pablo Picasso', 'El Tio Pepe Don José', '1905'),
#  ('Artist: Pablo Picasso', 'Bunch with Apple', 'January 22, 1956')]

# %% [markdown]
# Let's save that, so we can explore it.

# %%
picasso = _

# %%
picasso
# Out:
# [('Artist: Pablo Picasso', 'Taureau de Profil', '1945'),
#  ('Artist: Pablo Picasso', 'Le Combat', '1937'),
#  ('Artist: Pablo Picasso', 'Les pauvres', '1905 (printed 1913)'),
#  ('Artist: Pablo Picasso', 'Après la Pique', '1959'),
#  ('Artist: Pablo Picasso; Publisher: Ambroise Vollard; Printer: Louis Fort, Paris, France', 'Les deux saltimbanques', '1905 (published 1913)'),
#  ('Artist: Pablo Picasso', 'Tête de Femme de Profil', '1905 (printed 1913)'),
#  ("Artist: Pablo Picasso; Printer: L'Atelier Desjobert, Paris", 'Le Peintre et son Modèle', '1930'),
#  ('Artist: Pablo Picasso', 'Le Singe', '1936'),
#  ('Artist: Pablo Picasso; Printer: Auguste Delâtre', 'Le repas frugal', 'September 1904 (printed 1913)'),
#  ('Artist: Pablo Picasso; Printer: Aldo Crommelyck', 'Painter at Work with a Bearded Model and a Seated Spectator', '1963'),
#  ('Artist: Pablo Picasso', 'Portrait of Ambrose Vollard, II', '1937 (printed and published 1939)'),
#  ('Artist: Pablo Picasso', 'Portrait of Ambroise Vollard, III', '1937 (printed and published 1939)'),
#  ('Artist: Pablo Picasso; Publisher: Mourlot Freres, Paris', 'Hibou, verre at fleur', '1956'),
#  ('Artist: Pablo Picasso', 'A Disheveled Woman', '1901'),
#  ('Maker: Pablo Picasso', 'Stirrup jar', 'c. 1950'),
#  ('Artist: Pablo Picasso; Printer: Arnéra, Vallauris, France', 'Le Banderillero (first state)', '1959'),
#  ('Artist: Pablo Picasso; Printer: Arnéra, Vallauris, France', 'Le Banderillero (fourth state)', '1959'),
#  ('Artist: Pablo Picasso; Printer: Arnéra, Vallauris, France', 'Le Banderillero (third state)', '1959'),
#  ('Artist: Pablo Picasso; Printer: Arnéra, Vallauris, France', 'Le Banderillero (second state)', '1959'),
#  ('Artist: Pablo Picasso; Author: Poem by Pablo Picasso', 'Text page from Sueño y Mentira de Franco (The Dream and Lie of Franco)', '1937'),
#  ('Artist: Pablo Picasso; Author: Pablo Picasso; Publisher: Pablo Picasso', 'Cover from Sueño y Mentira de Franco (Dream and Lie of Franco)', 'January 8 and 9, June 7, 1937'),
#  ('Artist: Pablo Picasso; Printer: Atelier Roger Lacourière, Paris, France (etchings)', 'Dream and Lie of Franco, Plate 1', 'January 8, 1937'),
#  ('Artist: Pablo Picasso; Printer: Atelier Roger Lacourière, Paris, France (etchings)', 'Dream and Lie of Franco, Plate 2', 'January 8 and 9, June 7, 1937'),
#  ('Artist: Pablo Picasso; Maker: Madoura Pottery, Vallauris, France', 'Vase', '1950'),
#  ('Maker: Pablo Picasso', 'Face No.111', '1963'),
#  ('Maker: Pablo Picasso', 'Joie de Vivre', 'c. 1956'),
#  ('Artist: Pablo Picasso; Publisher: Berggruen and Company', "Cover for an Exhibition Catalogue: Picasso, Dessins d'un Demi-Siècle", '1956'),
#  ('Artist: Pablo Picasso', 'Baboon and Young', '1951'),
#  ('Artist: Pablo Picasso', 'Reclining Woman', '1920'),
#  ('Artist: Pablo Picasso', 'Woman in an Armchair', '1927'),
#  ('Artist: Pablo Picasso', 'Woman by the Sea', '1922'),
#  ('Artist: Pablo Picasso', 'The Water Carrier', '1904-1905'),
#  ('Artist: Pablo Picasso; Author: Pierre Reverdy', 'Page from Le Chant des Morts (The Song of the Dead)', '1948'),
#  ('Artist: Pablo Picasso; Author: Honoré de Balzac; Publisher: Ambroise Vollard; Woodcutter: Wood engraving by Georges Aubert, Paris, France; Printer: L ... (5 characters truncated) ... Fort, Paris, France (etchings); Printer: Georges Aubert, Paris, France (wood engravings); Printer: Aimé Jourde, Paris, France , (text and typography)', "Le chef d'oeuvre Inconnu (The Unknown Masterpiece)", '1931'),
#  ('Artist: Pablo Picasso; Author: Poems by Pierre Reverdy; Publisher: Tériade, Paris, France; Printer: Draeger Frères, Paris, France , (text and type); Lithographer: Printed by Mourlot Freres, Paris (lithography)', 'Le Chant des Morts (The Song of the Dead)', 'September 30, 1948'),
#  ('Artist: Pablo Picasso; Author: Georges Louis Leclerc, Comte de Buffon; Publisher: Martin Fabiani, Paris', 'The Cow from Histoire Naturelle (Natural History)', '1942'),
#  ('Artist: Pablo Picasso; Author: Pierre Reverdy', 'Cover from Le Chant des Morts (The Song of the Dead)', '1948'),
#  ('Artist: Pablo Picasso; Author: Georges Louis Leclerc, Comte de Buffon; Printer: Atelier Roger Lacourière, Paris, France , (prints); Printer: Fequet et Baudier, Paris, France , (text); Publisher: Martin Fabiani, Paris', "Histoire naturelle: Eaux-fortes originales pour les textes de Buffon (Natural History: Original Etchings for Buffon's Text)", '1936 (published 1942)'),
#  ('Artist: Pablo Picasso; Author: Georges Louis Leclerc, Comte de Buffon; Publisher: Martin Fabiani, Paris', 'The Donkey, from Histoire Naturelle (Natural History)', '1942'),
#  ('Artist: Pablo Picasso; Author: Georges Louis Leclerc, Comte de Buffon; Publisher: Martin Fabiani, Paris', 'The Horse, from Histoire Naturelle (Natural History)', '1942'),
#  ('Artist: Pablo Picasso; Author: Poems by Aimé Césaire; Publisher: Éditions Fragrance , Paris; Printer: Pierre Bouchet, Paris, France (text and typography); Printer: Atelier Roger Lacourière, Paris, France (prints)', 'Corps Perdu (Lost Body)', '1950'),
#  ('Artist: Pablo Picasso; Author: Pierre Reverdy', 'Title page from Le Chant des Morts (The Song of the Dead)', '1948'),
#  ('Maker: Pablo Picasso', 'Pigeon et ses Petits', '1947'),
#  ('Artist: Pablo Picasso', 'Bullfight', '20th century'),
#  ('Artist: Pablo Picasso', 'Portrait of Ambrose Vollard, II', '1937 (printed and published 1939)'),
#  ('Artist: Pablo Picasso', 'Plate', 'c. 1950'),
#  ('Artist: Pablo Picasso', 'Bird', '20th century'),
#  ('Artist: After Pablo Picasso', 'Pas de deux', '1925'),
#  ('Artist: Pablo Picasso; Author: Prosper Mérimée; Publisher: La Bibliotèque Française; Printer: Atelier Lacourière et Frélaut, Paris, France (engravings, aquatints); Printer: Imprimerie Union, Paris , (text and type)', 'Carmen', '1949'),
#  ('Artist: after Pablo Picasso; Publisher: Paul Rosenberg &amp; Co.', 'Le Tricorne (Three-cornered Hat)', '1920'),
#  ('Artist: Pablo Picasso; Author: Poems by Luis de Góngora y Argote; Translator: Z. Millner; Publisher: Les Grands Peintres, Modernes et le Livre, Paris ... (9 characters truncated) ...  Printer: Fequet et Baudier, Paris, France , (text); Printer: Atelier Roger Lacourière, Paris, France , (etchings); Book Binder: Pierre-Lucien Martin', 'Vingt poèmes de Góngora (Twenty Poems by Góngora)', '1948'),
#  ("Artist: Pablo Picasso; Author: Text attributed to Fernando de Rojas; Publisher: Editions de l'Atelier Crommelynck, Paris, France; Printer: Fequet et Baudier, Paris, France (text and typography); Printer: Atelier Crommelynck, Paris (etchings)", 'La Celestine (Carlota Valdivia)', '1971'),
#  ('Artist: Illustrations by Pablo Picasso; Author: Honoré de Balzac; Artist: Hand-painted chemise, slipcase, and endleaves by John Graham; Engraver: Woo ... (110 characters truncated) ... ouis Fort, Paris, France (etchings); Printer: Georges Aubert, Paris, France (wood engravings); Printer: Aimé Jourde, Paris, France (text, typography)', "Le Chef-d'oeuvre inconnu", '1931'),
#  ('Artist: Pablo Picasso', 'Faun Uncovering a Woman', '1936'),
#  ('Artist: Pablo Picasso', 'Vase', '1952'),
#  ('Artist: Pablo Picasso', 'Ex-Libris for Max Pellequer', '1930'),
#  ('Artist: Pablo Picasso; Author: Poems by Tristan Tzara; Publisher: Bordas, Paris, France; Lithographer: Printed by Mourlot Freres, Paris (lithographs); Printer: George Girard, Paris, France (text and typography)', "De Mémoire d'Homme (In Living Memory)", '1950'),
#  ('Artist: Pablo Picasso; Author: Michael Leiris; Publisher: Harcourt, Brace, Jovanovich Inc., New York; Publisher: Éditions de la Revue Verve, Paris; Printer: Draeger Frères, Paris, France , Paris; Printer: Mourlot Freres, Paris', 'Revue Verve: Picasso and the Human Comedy or the Avatars of Fat-Foot', '1954'),
#  ('Artist: Pablo Picasso; Author: Aristophanes; Translator: Gilbert Seldes; Publisher: The Limited Editions Club; Printer: The Limited Editions Club (text, typography, and reproductions); Printer: Atelier Lacourière et Frélaut, Paris, France (etchings)', 'Lysistrata', '1934'),
#  ('Artist: Pablo Picasso', 'Minotaure aveugle guidé par une fillette, III', '1934'),
#  ('Artist: Pablo Picasso', 'Portrait of Ambrose Vollard, II', '1937 (printed and published 1939)'),
#  ('Artist: Pablo Picasso', 'Figure with Striped Blouse', '1949'),
#  ('Artist: Pablo Picasso; Publisher: Atelier Roger Lacourière, Paris, France; Printer: Atelier Roger Lacourière, Paris, France', 'Femme torero. Dernier baiser?', 'June 12, 1934'),
#  ('Artist: Pablo Picasso; Publisher: Atelier Roger Lacourière, Paris, France; Printer: Atelier Roger Lacourière, Paris, France', 'La Grande corrida, avec femme torero', 'September 8,1934'),
#  ('Artist: Pablo Picasso', 'Portrait of D. H. Kahnweiler I', '1957'),
#  ('Artist: Pablo Picasso', 'Portrait of D. H. Kahnweiler II', '1957'),
#  ('Artist: Pablo Picasso', 'The Studio', '1948'),
#  ('Artist: Pablo Picasso', 'Les Trois Amies (The Three Friends)', '1927'),
#  ('Artist: Pablo Picasso', 'Portrait of D.H. Kahnweiler III', '1957'),
#  ('Artist: Pablo Picasso', 'Venus and Cupid', '1949'),
#  ('Author: Avant-propos by Albert Gleizes; Author: Epilogue by Jean Metzinger; Artist: after Georges Braque; Artist: after André Derain; Artist: Marcel  ... (173 characters truncated) ... o Picasso; Artist: Jacques Villon; Printer: Compagnie Française des Arts Graphiques, Paris; Publisher: Compagnie Française des Arts Graphiques, Paris', 'Du Cubisme', '1947'),
#  ('Artist: Pablo Picasso; Printer: Arnéra, Vallauris, France', 'Le Banderillero (pre-first state)', '1959'),
#  ("Artist: after Pablo Picasso; Author: Preface by Jaime Sabartès; Printer: Atelier Crommelynck, Paris; Colorist: Daniel Jacomet et Cie, Paris; Publisher: Au Vent d'Arles", 'Les Bleus de Barcelone', '1963'),
#  ('Artist: Pablo Picasso', 'Paysage a Vallauris', '1953'),
#  ('Photographer: David Seymour; Publisher: The International Center for Photography; Depicted: Pablo Picasso', 'Pablo Picasso and detail of "Guernica," France', '1937'),
#  ('Artist: Pablo Picasso', 'Pitcher', 'c. 1950'),
#  ('Artist: Pablo Picasso; Author: Robert Desnos; Publisher: Robert J. Godet, Paris, France', 'Contrée', '1944'),
#  ('Artist: Pablo Picasso', 'El Tio Pepe Don José', '1905'),
#  ('Artist: Pablo Picasso', 'Bunch with Apple', 'January 22, 1956')]

# %%
3 + 4
# Out:
# 7

# %%
x = _

# %%
x
# Out:
# 7

# %% [markdown]
# The sql magic provides us with a lot of very nice utilities, for example we can convert directly to a DataFrame.

# %%
picasso.DataFrame().head()
# Out:
#                                               artist                   title  \
# 0                              Artist: Pablo Picasso       Taureau de Profil
# 1                              Artist: Pablo Picasso               Le Combat
# 2                              Artist: Pablo Picasso             Les pauvres
# 3                              Artist: Pablo Picasso          Après la Pique
# 4  Artist: Pablo Picasso; Publisher: Ambroise Vol...  Les deux saltimbanques
#
#                    dated
# 0                   1945
# 1                   1937
# 2    1905 (printed 1913)
# 3                   1959
# 4  1905 (published 1913)

# %% [markdown]
# The output is a `ResultSet` that we can manipulate directly if we wish.

# %%
type(picasso)
# Out:
# sql.run.ResultSet

# %%
[obj.title for obj in picasso]
# Out:
# ['Taureau de Profil',
#  'Le Combat',
#  'Les pauvres',
#  'Après la Pique',
#  'Les deux saltimbanques',
#  'Tête de Femme de Profil',
#  'Le Peintre et son Modèle',
#  'Le Singe',
#  'Le repas frugal',
#  'Painter at Work with a Bearded Model and a Seated Spectator',
#  'Portrait of Ambrose Vollard, II',
#  'Portrait of Ambroise Vollard, III',
#  'Hibou, verre at fleur',
#  'A Disheveled Woman',
#  'Stirrup jar',
#  'Le Banderillero (first state)',
#  'Le Banderillero (fourth state)',
#  'Le Banderillero (third state)',
#  'Le Banderillero (second state)',
#  'Text page from Sueño y Mentira de Franco (The Dream and Lie of Franco)',
#  'Cover from Sueño y Mentira de Franco (Dream and Lie of Franco)',
#  'Dream and Lie of Franco, Plate 1',
#  'Dream and Lie of Franco, Plate 2',
#  'Vase',
#  'Face No.111',
#  'Joie de Vivre',
#  "Cover for an Exhibition Catalogue: Picasso, Dessins d'un Demi-Siècle",
#  'Baboon and Young',
#  'Reclining Woman',
#  'Woman in an Armchair',
#  'Woman by the Sea',
#  'The Water Carrier',
#  'Page from Le Chant des Morts (The Song of the Dead)',
#  "Le chef d'oeuvre Inconnu (The Unknown Masterpiece)",
#  'Le Chant des Morts (The Song of the Dead)',
#  'The Cow from Histoire Naturelle (Natural History)',
#  'Cover from Le Chant des Morts (The Song of the Dead)',
#  "Histoire naturelle: Eaux-fortes originales pour les textes de Buffon (Natural History: Original Etchings for Buffon's Text)",
#  'The Donkey, from Histoire Naturelle (Natural History)',
#  'The Horse, from Histoire Naturelle (Natural History)',
#  'Corps Perdu (Lost Body)',
#  'Title page from Le Chant des Morts (The Song of the Dead)',
#  'Pigeon et ses Petits',
#  'Bullfight',
#  'Portrait of Ambrose Vollard, II',
#  'Plate',
#  'Bird',
#  'Pas de deux',
#  'Carmen',
#  'Le Tricorne (Three-cornered Hat)',
#  'Vingt poèmes de Góngora (Twenty Poems by Góngora)',
#  'La Celestine (Carlota Valdivia)',
#  "Le Chef-d'oeuvre inconnu",
#  'Faun Uncovering a Woman',
#  'Vase',
#  'Ex-Libris for Max Pellequer',
#  "De Mémoire d'Homme (In Living Memory)",
#  'Revue Verve: Picasso and the Human Comedy or the Avatars of Fat-Foot',
#  'Lysistrata',
#  'Minotaure aveugle guidé par une fillette, III',
#  'Portrait of Ambrose Vollard, II',
#  'Figure with Striped Blouse',
#  'Femme torero. Dernier baiser?',
#  'La Grande corrida, avec femme torero',
#  'Portrait of D. H. Kahnweiler I',
#  'Portrait of D. H. Kahnweiler II',
#  'The Studio',
#  'Les Trois Amies (The Three Friends)',
#  'Portrait of D.H. Kahnweiler III',
#  'Venus and Cupid',
#  'Du Cubisme',
#  'Le Banderillero (pre-first state)',
#  'Les Bleus de Barcelone',
#  'Paysage a Vallauris',
#  'Pablo Picasso and detail of "Guernica," France',
#  'Pitcher',
#  'Contrée',
#  'El Tio Pepe Don José',
#  'Bunch with Apple']

# %% [markdown]
# We can also capture the output directly in a variable. Let's just get the artist, title, and date, this time for Van Gogh.

# %%
van_gogh = %sql SELECT artist, title, dated FROM mia WHERE artist ILIKE '%van gogh%' ORDER BY index
van_gogh
# Out:
#  * postgresql://rich:***@localhost:5432/art
# 3 rows affected.
# [('Artist: Vincent van Gogh', 'Portrait of Dr. Gachet (Auvers-sur-Oise)', 'May 15, 1890'),
#  ('Artist: Vincent van Gogh', 'View of the Field behind Saint Paul’s Asylum in Saint-Rémy-de-Provence', '1889'),
#  ('Artist: Vincent van Gogh', 'Olive Trees', '1889')]

# %%
van_gogh.DataFrame()
# Out:
#                      artist  \
# 0  Artist: Vincent van Gogh
# 1  Artist: Vincent van Gogh
# 2  Artist: Vincent van Gogh
#
#                                                title         dated
# 0           Portrait of Dr. Gachet (Auvers-sur-Oise)  May 15, 1890
# 1  View of the Field behind Saint Paul’s Asylum i...          1889
# 2                                        Olive Trees          1889

# %%
# %sql sqlite:///customers.sqlite

# %%
# %%sql
#
# SELECT *
# FROM customers
# LIMIT 5
# Out:
#    postgresql://rich:***@localhost:5432/art
#  * sqlite:///customers.sqlite
# Done.
# [(1, 'Katie Baker', '13083', 54),
#  (2, 'Mary Clarkson', '07852', 20),
#  (3, 'Michelle Reynolds', '06403', 26),
#  (5, "Valerie O'Brian", '11386', None),
#  (7, 'Katherine Diamond', '08605', 26)]

# %% [markdown]
# This is great for exploring and playing around in our notebook.
#
# But we'll want to make an actual tool, that will be more user friendly. We shouldn't expect our users to know SQL, and we don't want to overwhelm them with too many results - or run out of memory! Let's create a function they can call that will let them enter an artist and give them a page back at a time. Eventually we'll want to move this to a `.py` file, so we can call it in a utility.
#
# The sql magic doesn't work outside of notebooks.  Instead, we need a SQL connector. Each flavor of SQL has its own. The one for Postgres is called `psycopg2`. Connecting is similar, but we also need to create a `cursor` object to actually run queries.

# %%
connect_string = 'postgresql://rich:testpass@localhost:5432/art'

# %%
import psycopg2

connection = psycopg2.connect(connect_string)
cursor = connection.cursor()

# %%
cursor.execute('SELECT * FROM mia LIMIT 5;')

# %% [markdown]
# We can fetch one line at a time, or all lines.  This is an iterator, so it's a one way trip.

# %%
cursor.fetchone()
# Out:
# (10583,
#  'P.70.72',
#  'Artist: Francisco Toledo',
#  'Mexican, 1940 - 2019',
#  'Benda Hua',
#  ' Prints',
#  'Arts of the Americas',
#  'North America',
#  'Mexico',
#  None,
#  'Gift of Mrs. Patrick Butler, by exchange',
#  'c. 1969',
#  'Woman swimming underwater, with shrimp caught in a fishing net',
#  None,
#  'White-line etching and drypoint (top-rolled)',
#  '20th century',
#  '',
#  'Numbered in pencil, LL: 1/25',
#  'Not on View')

# %%
rest = cursor.fetchall()

# %%
len(rest)
# Out:
# 4

# %%
cursor.fetchall()
# Out:
# []

# %%
import sqlite3

conn_lite = sqlite3.connect("customers.sqlite")
cursor_lite = conn_lite.cursor()
cursor_lite.execute("SELECT * FROM customers LIMIT 5")
cursor_lite.fetchall()
# Out:
# [(1, 'Katie Baker', '13083', 54),
#  (2, 'Mary Clarkson', '07852', 20),
#  (3, 'Michelle Reynolds', '06403', 26),
#  (5, "Valerie O'Brian", '11386', None),
#  (7, 'Katherine Diamond', '08605', 26)]

# %% [markdown]
# This tool works fine, but only for Postgres.  There are connectors for SQLite (the `sqlite3` package), MySQL (the `mysql` package), etc. But there's also a higher level package that will connect to any flavor, SQLAlchemy. This is a much better choice: we only have to learn one package, we can switch databases using basically the same code, and SQLAlchemy provides more advanced tools (we won't get into those today).
#
# Note the slight change in syntax.

# %%
import sqlalchemy

engine = sqlalchemy.create_engine(connect_string)
conn = engine.connect()

# %%
response = conn.execute("SELECT * FROM mia LIMIT 5;")

# %%
response

# %%
results = response.fetchall()

# %%
columns = response.keys()

# %%
response.fetchall()
# Out:
# []

# %%
len(results)
# Out:
# 5

# %%
results
# Out:
# [(10583, 'P.70.72', 'Artist: Francisco Toledo', 'Mexican, 1940 - 2019', 'Benda Hua', ' Prints', 'Arts of the Americas', 'North America', 'Mexico', None, 'Gift of Mrs. Patrick Butler, by exchange', 'c. 1969', 'Woman swimming underwater, with shrimp caught in a fishing net', None, 'White-line etching and drypoint (top-rolled)', '20th century', '', 'Numbered in pencil, LL: 1/25', 'Not on View'),
#  (10584, 'P.11,377', 'Artist: Philip Little', 'American, 1857 - 1942', 'Outer Harbor, Gloucester', ' Prints', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Philip Little in memory of Annie Jeannette Jackson, 1931', '1915', '', None, 'Etching', '20th century', '', '', 'Not on View'),
#  (10585, 'P.13,434', 'Artist: Clara Gardner Mairs', 'American, 1878 - 1963', 'Shadrack Meshach and Abendigo', ' Prints', 'Prints and Drawings', 'North America', 'United States', None, 'Gift of Clement Haupers, 1965', '20th century', '', None, 'Etching, aquatint on cream wove paper', '20th century', '', '', 'Not on View'),
#  (10586, 'P.82.40.245', 'Artist: Winslow Homer', 'American, 1836–1910', "On the Beach at Long Branch - The Children's Hour", ' Prints', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Dr. and Mrs. Robert D. Semsch', '1874', '', None, 'Wood engraving', '19th century', '', '', 'Not on View'),
#  (10587, 'P.11,368', 'Artist: Philip Little', 'American, 1857 - 1942', "The Voyagers - Mother's Tablecloth", ' Prints', 'Arts of the Americas', 'North America', 'United States', None, 'Gift of Philip Little in memory of Annie Jeannette Jackson, 1931', '1919', '', None, 'Etching', '20th century', '', '', 'Not on View')]

# %% [markdown]
# We can use the column names to make a DataFrame.  In fact, the sql magic is doing precisely this under the hood, it calls SQLAlchemy.  SQLAlchemy delegates the actual connecting to `psycopg2` (or `sqlite3`, etc), so we'll need both installed.

# %%
import pandas as pd

pd.DataFrame(results, columns=columns)
# Out:
#    index accession_number                       artist              life_date  \
# 0  10583          P.70.72     Artist: Francisco Toledo   Mexican, 1940 - 2019
# 1  10584         P.11,377        Artist: Philip Little  American, 1857 - 1942
# 2  10585         P.13,434  Artist: Clara Gardner Mairs  American, 1878 - 1963
# 3  10586      P.82.40.245        Artist: Winslow Homer    American, 1836–1910
# 4  10587         P.11,368        Artist: Philip Little  American, 1857 - 1942
#
#                                                title classification  \
# 0                                          Benda Hua         Prints
# 1                           Outer Harbor, Gloucester         Prints
# 2                      Shadrack Meshach and Abendigo         Prints
# 3  On the Beach at Long Branch - The Children's Hour         Prints
# 4                 The Voyagers - Mother's Tablecloth         Prints
#
#              department      continent        country culture  \
# 0  Arts of the Americas  North America         Mexico    None
# 1  Arts of the Americas  North America  United States    None
# 2   Prints and Drawings  North America  United States    None
# 3  Arts of the Americas  North America  United States    None
# 4  Arts of the Americas  North America  United States    None
#
#                                           creditline         dated  \
# 0           Gift of Mrs. Patrick Butler, by exchange       c. 1969
# 1  Gift of Philip Little in memory of Annie Jeann...          1915
# 2                      Gift of Clement Haupers, 1965  20th century
# 3              Gift of Dr. and Mrs. Robert D. Semsch          1874
# 4  Gift of Philip Little in memory of Annie Jeann...          1919
#
#                                          description dimensions  \
# 0  Woman swimming underwater, with shrimp caught ...       None
# 1                                                          None
# 2                                                          None
# 3                                                          None
# 4                                                          None
#
#                                          medium         style text  \
# 0  White-line etching and drypoint (top-rolled)  20th century
# 1                                       Etching  20th century
# 2         Etching, aquatint on cream wove paper  20th century
# 3                                Wood engraving  19th century
# 4                                       Etching  20th century
#
#                        markings         room
# 0  Numbered in pencil, LL: 1/25  Not on View
# 1                                Not on View
# 2                                Not on View
# 3                                Not on View
# 4                                Not on View

# %% [markdown]
# Now our query is just a string!  We can manipulate that to get what we want. Note that we'll need to double our `%` to `%%` here, as SQLAlchemy uses the `%` for string formatting.

# %%
artist = 'Van Gogh'

query = f"""
SELECT artist, title, dated
FROM mia
WHERE artist ILIKE '%%{artist.lower()}%%'
ORDER BY index
"""

conn.execute(query).fetchall()
# Out:
# [('Artist: Vincent van Gogh', 'Portrait of Dr. Gachet (Auvers-sur-Oise)', 'May 15, 1890'),
#  ('Artist: Vincent van Gogh', 'View of the Field behind Saint Paul’s Asylum in Saint-Rémy-de-Provence', '1889'),
#  ('Artist: Vincent van Gogh', 'Olive Trees', '1889')]

# %% [markdown]
# We saw that Picasso had a lot of results, so we'll use our `OFFSET` and `LIMIT` to page through it.

# %%
artist = 'Picasso'
offset = 10
limit = 10

query = f"""
SELECT artist, title, dated
FROM mia
WHERE artist ILIKE '%%{artist.lower()}%%'
ORDER BY index
OFFSET {offset} LIMIT {limit}
"""

conn.execute(query).fetchall()
# Out:
# [('Artist: Pablo Picasso', 'Tête de Femme de Profil', '1905 (printed 1913)'),
#  ("Artist: Pablo Picasso; Printer: L'Atelier Desjobert, Paris", 'Le Peintre et son Modèle', '1930'),
#  ('Artist: Pablo Picasso', 'Le Singe', '1936'),
#  ('Artist: Pablo Picasso; Printer: Auguste Delâtre', 'Le repas frugal', 'September 1904 (printed 1913)'),
#  ('Artist: Pablo Picasso; Printer: Aldo Crommelyck', 'Painter at Work with a Bearded Model and a Seated Spectator', '1963'),
#  ('Artist: Pablo Picasso', 'Portrait of Ambrose Vollard, II', '1937 (printed and published 1939)'),
#  ('Artist: Pablo Picasso', 'Portrait of Ambroise Vollard, III', '1937 (printed and published 1939)'),
#  ('Artist: Pablo Picasso; Publisher: Mourlot Freres, Paris', 'Hibou, verre at fleur', '1956'),
#  ('Artist: Pablo Picasso', 'A Disheveled Woman', '1901'),
#  ('Maker: Pablo Picasso', 'Stirrup jar', 'c. 1950')]

# %%
'picasso;DROP TABLE mia;--'

# %% [markdown]
# Great, now we can page through the results.  But this is dangerous!  We are vulnerable to SQL injection attacks - a sufficiently malicious artist name could cause a problem.  SQLAlchemy lets us get around this, and actually makes our job easier too.

# %%
artist_wildcard = f'%{artist.lower()}%'

query = """
SELECT index, artist, title, dated
FROM mia
WHERE artist ILIKE %s
ORDER BY index
OFFSET %s LIMIT %s
"""

conn.execute(query, artist_wildcard, offset, limit).fetchall()
# Out:
# [(10994, 'Artist: Pablo Picasso', 'Tête de Femme de Profil', '1905 (printed 1913)'),
#  (11000, "Artist: Pablo Picasso; Printer: L'Atelier Desjobert, Paris", 'Le Peintre et son Modèle', '1930'),
#  (11011, 'Artist: Pablo Picasso', 'Le Singe', '1936'),
#  (11269, 'Artist: Pablo Picasso; Printer: Auguste Delâtre', 'Le repas frugal', 'September 1904 (printed 1913)'),
#  (11304, 'Artist: Pablo Picasso; Printer: Aldo Crommelyck', 'Painter at Work with a Bearded Model and a Seated Spectator', '1963'),
#  (11333, 'Artist: Pablo Picasso', 'Portrait of Ambrose Vollard, II', '1937 (printed and published 1939)'),
#  (11423, 'Artist: Pablo Picasso', 'Portrait of Ambroise Vollard, III', '1937 (printed and published 1939)'),
#  (15231, 'Artist: Pablo Picasso; Publisher: Mourlot Freres, Paris', 'Hibou, verre at fleur', '1956'),
#  (18541, 'Artist: Pablo Picasso', 'A Disheveled Woman', '1901'),
#  (19038, 'Maker: Pablo Picasso', 'Stirrup jar', 'c. 1950')]

# %% [markdown]
# Alright, let's put that in a function.  We'll return the output as a DataFrame.

# %%
def artist_objects(connection_string, artist, results_per_page=10, page_number=0):
    offset = results_per_page * page_number
    artist_wildcard = f'%{artist.lower()}%'
    
    query = """
    SELECT index, artist, title, dated
    FROM mia
    WHERE artist ILIKE %s
    ORDER BY index
    OFFSET %s LIMIT %s
    """
    
    engine = sqlalchemy.create_engine(connection_string)
    conn = engine.connect()
    
    response = conn.execute(query, artist_wildcard, offset, limit)
    
    columns = response.keys()
    objects = response.fetchall()
    
    return pd.DataFrame(objects, columns=columns)

# %%
artist_objects(connect_string, 'picasso', 5, 0)
# Out:
#    index                                             artist  \
# 0    623  Photographer: David Seymour; Publisher: The In...
# 1   3591                              Artist: Pablo Picasso
# 2   8498  Artist: Pablo Picasso; Author: Robert Desnos; ...
# 3   8515                              Artist: Pablo Picasso
# 4   8637                              Artist: Pablo Picasso
# 5  10621                              Artist: Pablo Picasso
# 6  10697                              Artist: Pablo Picasso
# 7  10737                              Artist: Pablo Picasso
# 8  10821                              Artist: Pablo Picasso
# 9  10928  Artist: Pablo Picasso; Publisher: Ambroise Vol...
#
#                                             title                  dated
# 0  Pablo Picasso and detail of "Guernica," France                   1937
# 1                                         Pitcher                c. 1950
# 2                                         Contrée                   1944
# 3                            El Tio Pepe Don José                   1905
# 4                                Bunch with Apple       January 22, 1956
# 5                               Taureau de Profil                   1945
# 6                                       Le Combat                   1937
# 7                                     Les pauvres    1905 (printed 1913)
# 8                                  Après la Pique                   1959
# 9                          Les deux saltimbanques  1905 (published 1913)

# %% [markdown]
# We'll probably want to display a "items 10 - 15 out of 79" for our users.  Let's make a separate function for that.

# %%
def artist_count(connection_string, artist, results_per_page=10, page_number=0):
    offset = results_per_page * page_number # zero based page counting
    artist_wildcard = f'%{artist.lower()}%'
    
    query = f"""
    SELECT COUNT(*)
    FROM mia
    WHERE artist ILIKE %s
    """
    
    engine = sqlalchemy.create_engine(connection_string)
    conn = engine.connect()
    
    response = conn.execute(query, artist_wildcard)
    
    total = response.fetchone()[0]
    
    high = min(offset + results_per_page - 1, total)
    
    return {"low": offset, "high": high, "total": total}

# %%
artist_count(connect_string, 'picasso', 5, 5)
# Out:
# {'low': 25, 'high': 29, 'total': 79}

# %% [markdown]
# Let's put these in a `.py` file, so we can call them from non-notebook locations, and no longer have to worry about the SQL aspect.

# %%
# See the artist_search.py file

# %% [markdown]
# At this point we could build a website or other interface.  Instead, let's go simple and just mock up an interface.

# %%
# see the menu.py file
